# %%
# !curl -LsSf https://raw.githubusercontent.com/gboeing/ppd534/refs/heads/2026/colab-installer.sh | bash

# %%
import geopandas

url = "https://raw.githubusercontent.com/gboeing/ppd534/main/data/tl_2017_06_tract/tl_2017_06_tract.shp"
gdf = geopandas.read_file(url)
gdf.shape
